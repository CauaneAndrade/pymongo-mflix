# %%
# import the pymongo library - this is the Python driver!
import pymongo

# replace "uri" with your Atlas URI string - should look like mongodb+srv://...
uri = "mongodb+srv://m220cauane:m220cauane@mflix-c0bjg.azure.mongodb.net/test?retryWrites=true&w=majority"
client = pymongo.MongoClient(uri)
mflix = client.sample_mflix

# movies is our collection handle - it refers to the sample_mflix.movies collection
movies = mflix.movies

# %%
movies
# Out:
# Collection(Database(MongoClient(host=['mflix-shard-00-00-c0bjg.azure.mongodb.net:27017', 'mflix-shard-00-01-c0bjg.azure.mongodb.net:27017', 'mflix-shard-00-02-c0bjg.azure.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='mflix-shard-0', ssl=True, retrywrites=True, w='majority'), 'sample_mflix'), 'movies')

# %%
# find one document in the "movies" collection - does not matter which one
movies.find_one()
# Out:
# {'_id': ObjectId('573a1390f29313caabcd4135'),
#  'plot': 'Three men hammer on an anvil and pass a bottle of beer around.',
#  'genres': ['Short'],
#  'runtime': 1,
#  'cast': ['Charles Kayser', 'John Ott'],
#  'num_mflix_comments': 1,
#  'title': 'Blacksmith Scene',
#  'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.',
#  'countries': ['USA'],
#  'released': datetime.datetime(1893, 5, 9, 0, 0),
#  'directors': ['William K.L. Dickson'],
#  'rated': 'UNRATED',
#  'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  'lastupdated': '2015-08-26 00:03:50.133000000',
#  'year': 1893,
#  'imdb': {'rating': 6.2, 'votes': 1189, 'id': 5},
#  'type': 'movie',
#  'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 184, 'meter': 32},
#   'lastUpdated': datetime.datetime(2015, 6, 28, 18, 34, 9)}}

# %%
# find one document in the "movies" collection - must have "Salma Hayek" in the "cast"
movies.find_one( { "cast": "Salma Hayek" } )
# Out:
# {'_id': ObjectId('573a1399f29313caabceea6d'),
#  'plot': "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#  'genres': ['Action', 'Drama'],
#  'runtime': 95,
#  'rated': 'R',
#  'cast': ['David Arquette', 'John Hawkes', 'Salma Hayek', 'Jason Wiles'],
#  'num_mflix_comments': 1,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTgwMzU3MDI1NF5BMl5BanBnXkFtZTcwMDUwMTIyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'title': 'Roadracers',
#  'fullplot': "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#  'languages': ['English'],
#  'released': datetime.datetime(1994, 7, 22, 0, 0),
#  'directors': ['Robert Rodriguez'],
#  'writers': ['Robert Rodriguez', 'Tommy Nix'],
#  'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#  'lastupdated': '2015-09-01 00:53:54.567000000',
#  'year': 1994,
#  'imdb': {'rating': 6.7, 'votes': 2036, 'id': 111002},
#  'countries': ['USA'],
#  'type': 'movie',
#  'tomatoes': {'viewer': {'rating': 2.8, 'numReviews': 7487, 'meter': 31},
#   'dvd': datetime.datetime(2002, 9, 3, 0, 0),
#   'critic': {'rating': 4.9, 'numReviews': 23, 'meter': 26},
#   'lastUpdated': datetime.datetime(2015, 9, 11, 18, 0, 30),
#   'rotten': 17,
#   'production': 'Hollywood Pictures',
#   'fresh': 6}}

# %%
# find all the documents in the "movies" collection with "Salma Hayek" in the "cast"
# this returns a cursor, which IS a Python iterable, but is NOT a document!
movies.find( { "cast": "Salma Hayek" } )

# %%
# return the count of movies with "Salma Hayek" in the "cast"
movies.find( { "cast": "Salma Hayek" } ).count()

# %%
# find all movies with Salma Hayek
# then pretty print
cursor = movies.find( { "cast": "Salma Hayek" } )
from bson.json_util import dumps
print(dumps(cursor, indent=2))
# Out:
# [
#   {
#     "_id": {
#       "$oid": "573a1399f29313caabceea6d"
#     },
#     "plot": "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#     "genres": [
#       "Action",
#       "Drama"
#     ],
#     "runtime": 95,
#     "rated": "R",
#     "cast": [
#       "David Arquette",
#       "John Hawkes",
#       "Salma Hayek",
#       "Jason Wiles"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTgwMzU3MDI1NF5BMl5BanBnXkFtZTcwMDUwMTIyMQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Roadracers",
#     "fullplot": "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 774835200000
#     },
#     "directors": [
#       "Robert Rodriguez"
#     ],
#     "writers": [
#       "Robert Rodriguez",
#       "Tommy Nix"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-09-01 00:53:54.567000000",
#     "year": 1994,
#     "imdb": {
#       "rating": 6.7,
#       "votes": 2036,
#       "id": 111002
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 2.8,
#         "numReviews": 7487,
#         "meter": 31
#       },
#       "dvd": {
#         "$date": 1031011200000
#       },
#       "critic": {
#         "rating": 4.9,
#         "numReviews": 23,
#         "meter": 26
#       },
#       "lastUpdated": {
#         "$date": 1441994430000
#       },
#       "rotten": 17,
#       "production": "Hollywood Pictures",
#       "fresh": 6
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcef0b6"
#     },
#     "plot": "Based on the Nobel Prize Winner's novel, the Egyptian Naguib Mahfouz. The story, translated from El Cairo to Mexico City's downtown, narrates the life of the members of the neighbourhood ...",
#     "genres": [
#       "Drama"
#     ],
#     "runtime": 140,
#     "rated": "UNRATED",
#     "cast": [
#       "Ernesto G\u00e8mez Cruz",
#       "Mar\u00e8a Rojo",
#       "Salma Hayek",
#       "Bruno Bichir"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BNzM2NTRlNDMtMTBmMi00NTk0LTllMmQtNzQxMjQxOGFmOGQ3XkEyXkFqcGdeQXVyNjk1Njg5NTA@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Midaq Alley",
#     "fullplot": "Based on the Nobel Prize Winner's novel, the Egyptian Naguib Mahfouz. The story, translated from El Cairo to Mexico City's downtown, narrates the life of the members of the neighbourhood and the connection between them Don Ru, the owner of the local pub; Eusebia, his wife; Chava, his son and Abel his friend, who emigrate to USA in search of fortune; Susanita, the single landtender always dreaming to marry a good man; Guicho, the pub's employee, who extracts the money when Don Ru is not there and finally marries Susanita; Alma, the very good looking girl, the Abel's dream, who becomes a luxury prostitute while he's away; Jimmy, the handsome young man Don Ru becomes infatuated with, etc. This movie won the Ariel (the Mexican Oscar) as best movie in 1995.",
#     "languages": [
#       "Spanish"
#     ],
#     "released": {
#       "$date": 889142400000
#     },
#     "directors": [
#       "Jorge Fons"
#     ],
#     "writers": [
#       "Vicente Le\u00e8ero (screenplay)",
#       "Naguib Mahfouz (novel)"
#     ],
#     "awards": {
#       "wins": 27,
#       "nominations": 14,
#       "text": "27 wins & 14 nominations."
#     },
#     "lastupdated": "2015-09-01 01:14:01.613000000",
#     "year": 1995,
#     "imdb": {
#       "rating": 7.6,
#       "votes": 2013,
#       "id": 112619
#     },
#     "countries": [
#       "Mexico"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.5,
#         "numReviews": 721,
#         "meter": 79
#       },
#       "dvd": {
#         "$date": 982022400000
#       },
#       "lastUpdated": {
#         "$date": 1435430492000
#       }
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcef179"
#     },
#     "fullplot": "With this sequel to his prize-winning independent previous film, \"El Mariachi,\" director Robert Rodriquez joins the ranks of Sam Peckinpah and John Woo as a master of slick, glamorized ultra-violence. We pick up the story as a continuation of \"El Mariachi,\" where an itinerant musician, looking for work, gets mistaken for a hitman and thereby entangled in a web of love, corruption, and death. This time, he is out to avenge the murder of his lover and the maiming of his fretting hand, which occurred at the end of the earlier movie. However, the plot is recapitulated, and again, a case of mistaken identity leads to a very high body count, involvement with a beautiful woman who works for the local drug lord, and finally, the inevitable face-to-face confrontation and bloody showdown.",
#     "imdb": {
#       "rating": 7.2,
#       "votes": 127966,
#       "id": 112851
#     },
#     "year": 1995,
#     "plot": "A gunslinger is embroiled in a war with a local drug runner.",
#     "genres": [
#       "Action",
#       "Crime",
#       "Thriller"
#     ],
#     "rated": "R",
#     "metacritic": 55,
#     "title": "Desperado",
#     "lastupdated": "2015-08-29 00:25:05.467000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Robert Rodriguez"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.5,
#         "numReviews": 187644,
#         "meter": 80
#       },
#       "dvd": {
#         "$date": 867196800000
#       },
#       "critic": {
#         "rating": 6.4,
#         "numReviews": 39,
#         "meter": 62
#       },
#       "lastUpdated": {
#         "$date": 1442165457000
#       },
#       "rotten": 15,
#       "production": "Sony Pictures Home Entertainment",
#       "fresh": 24
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BYjA0NDMyYTgtMDgxOC00NGE0LWJkOTQtNDRjMjEzZmU0ZTQ3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 1,
#     "released": {
#       "$date": 809308800000
#     },
#     "awards": {
#       "wins": 0,
#       "nominations": 4,
#       "text": "4 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Antonio Banderas",
#       "Salma Hayek",
#       "Joaquim de Almeida",
#       "Cheech Marin"
#     ],
#     "directors": [
#       "Robert Rodriguez"
#     ],
#     "runtime": 104
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf092d"
#     },
#     "plot": "After a one night stand with Isabel, Alex realizes that she is pregnant and they decide to get married. However, along with the marriage comes compromise of one's own cultural traditions.",
#     "genres": [
#       "Comedy",
#       "Drama",
#       "Romance"
#     ],
#     "runtime": 109,
#     "metacritic": 37,
#     "rated": "PG-13",
#     "cast": [
#       "Matthew Perry",
#       "Salma Hayek",
#       "Jon Tenney",
#       "Carlos G\u00e8mez"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BM2Q3MzA3YmYtNzUzNS00NDhhLTkyZmYtMDU2YmE1ODY5MjdmXkEyXkFqcGdeQXVyNjQ2MjQ5NzM@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Fools Rush In",
#     "fullplot": "Sparks fly and cultures collide in this romantic comedy about a casual night of passion that turns into the love of a lifetime. Alex Whitman is a New Yorker sent to Las Vegas to oversee a construction project. There he meets Isabel Fuentes, and some serious chemistry brings them together for one night. But Alex doesn't see Isabel again until three months later, when he learns she is pregnant. On a whim and prayer, he proposes. However, there's more to marriage than a Vegas chapel and an Elvis impersonator, as Alex and Isabel soon learn.",
#     "languages": [
#       "English",
#       "Spanish"
#     ],
#     "released": {
#       "$date": 855878400000
#     },
#     "directors": [
#       "Andy Tennant"
#     ],
#     "writers": [
#       "Joan Taylor (story)",
#       "Katherine Reback (story)",
#       "Katherine Reback (screenplay)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 2,
#       "text": "2 nominations."
#     },
#     "lastupdated": "2015-09-07 00:52:44.310000000",
#     "year": 1997,
#     "imdb": {
#       "rating": 6.0,
#       "votes": 26104,
#       "id": 119141
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.0,
#         "numReviews": 62870,
#         "meter": 64
#       },
#       "dvd": {
#         "$date": 887068800000
#       },
#       "critic": {
#         "rating": 4.8,
#         "numReviews": 27,
#         "meter": 33
#       },
#       "lastUpdated": {
#         "$date": 1439923914000
#       },
#       "rotten": 18,
#       "production": "Sony Pictures Home Entertainment",
#       "fresh": 9
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf09f1"
#     },
#     "plot": "Based on the novel, a young gypsy becomes a Minister's obsession in 1483. Only the bell ringer and her husband and the court of miracles can save her.",
#     "genres": [
#       "Drama",
#       "Horror",
#       "Romance"
#     ],
#     "runtime": 98,
#     "cast": [
#       "Mandy Patinkin",
#       "Richard Harris",
#       "Salma Hayek",
#       "Edward Atterton"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTMxNTk1MTEyNV5BMl5BanBnXkFtZTcwMDk3MjYyMQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "The Hunchback",
#     "fullplot": "Based on the novel, a young gypsy becomes a Minister's obsession in 1483. Only the bell ringer and her husband and the court of miracles can save her.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 858470400000
#     },
#     "directors": [
#       "Peter Medak"
#     ],
#     "writers": [
#       "Victor Hugo (novel)",
#       "John Fasano (teleplay)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 12,
#       "text": "Nominated for 4 Primetime Emmys. Another 8 nominations."
#     },
#     "lastupdated": "2015-08-12 00:16:56.157000000",
#     "year": 1997,
#     "imdb": {
#       "rating": 6.2,
#       "votes": 1129,
#       "id": 119329
#     },
#     "countries": [
#       "USA",
#       "Hungary",
#       "Canada",
#       "Czech Republic"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 2.9,
#         "numReviews": 50,
#         "meter": 39
#       },
#       "dvd": {
#         "$date": 895536000000
#       },
#       "lastUpdated": {
#         "$date": 1438365919000
#       }
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0e4f"
#     },
#     "plot": "Famous 70s NYC nightclub seen and told through the eyes of a young employee.",
#     "genres": [
#       "Drama",
#       "Music"
#     ],
#     "runtime": 93,
#     "metacritic": 33,
#     "rated": "R",
#     "cast": [
#       "Ryan Phillippe",
#       "Salma Hayek",
#       "Neve Campbell",
#       "Mike Myers"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BYTIzNzIxMjEtZDNiZS00Y2E1LTkwOTItZGJjOTMwYzU4YzVmXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SY1000_SX677_AL_.jpg",
#     "title": "54",
#     "lastupdated": "2015-09-16 12:22:02.100000000",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 904262400000
#     },
#     "directors": [
#       "Mark Christopher"
#     ],
#     "writers": [
#       "Mark Christopher"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 7,
#       "text": "7 nominations."
#     },
#     "year": 1998,
#     "imdb": {
#       "rating": 5.8,
#       "votes": 26612,
#       "id": 120577
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.miramax.com/movie/54",
#       "viewer": {
#         "rating": 2.8,
#         "numReviews": 31237,
#         "meter": 44
#       },
#       "dvd": {
#         "$date": 986256000000
#       },
#       "critic": {
#         "rating": 4.2,
#         "numReviews": 66,
#         "meter": 15
#       },
#       "lastUpdated": {
#         "$date": 1440270591000
#       },
#       "consensus": "Poor plot development and slow pacing keep 54 from capturing the energy of it's legendary namesake.",
#       "rotten": 56,
#       "production": "Miramax Films",
#       "fresh": 10
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0ea6"
#     },
#     "fullplot": "\"Frida\" chronicles the life Frida Kahlo shared unflinchingly and openly with Diego Rivera, as the young couple took the art world by storm. From her complex and enduring relationship with her mentor and husband to her illicit and controversial affair with Leon Trotsky, to her provocative and romantic entanglements with women, Frida Kahlo lived a bold and uncompromising life as a political, artistic, and sexual revolutionary.",
#     "imdb": {
#       "rating": 7.4,
#       "votes": 57256,
#       "id": 120679
#     },
#     "year": 2002,
#     "plot": "A biography of artist Frida Kahlo, who channeled the pain of a crippling injury and her tempestuous marriage into her work.",
#     "genres": [
#       "Biography",
#       "Drama",
#       "Romance"
#     ],
#     "rated": "R",
#     "metacritic": 61,
#     "title": "Frida",
#     "lastupdated": "2015-09-12 00:33:36.510000000",
#     "languages": [
#       "English",
#       "French",
#       "Russian"
#     ],
#     "writers": [
#       "Hayden Herrera (book)",
#       "Clancy Sigal (screenplay)",
#       "Diane Lake (screenplay)",
#       "Gregory Nava (screenplay)",
#       "Anna Thomas (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.miramax.com/frida/",
#       "viewer": {
#         "rating": 3.7,
#         "numReviews": 53261,
#         "meter": 86
#       },
#       "dvd": {
#         "$date": 1055203200000
#       },
#       "critic": {
#         "rating": 6.9,
#         "numReviews": 151,
#         "meter": 76
#       },
#       "boxOffice": "$25.7M",
#       "consensus": "Frida is a passionate, visually striking biopic about the larger-than-life artist.",
#       "rotten": 36,
#       "production": "Miramax Films",
#       "lastUpdated": {
#         "$date": 1442167714000
#       },
#       "fresh": 115
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BYzUxMTU0ZmEtZWE0Ni00NzJlLThhZTUtNDA1ZDZjZDUxYThiXkEyXkFqcGdeQXVyNjk1Njg5NTA@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 2,
#     "released": {
#       "$date": 1037923200000
#     },
#     "awards": {
#       "wins": 19,
#       "nominations": 33,
#       "text": "Won 2 Oscars. Another 17 wins & 33 nominations."
#     },
#     "countries": [
#       "USA",
#       "Canada",
#       "Mexico"
#     ],
#     "cast": [
#       "Salma Hayek",
#       "M\u00e8a Maestro",
#       "Alfred Molina",
#       "Antonio Banderas"
#     ],
#     "directors": [
#       "Julie Taymor"
#     ],
#     "runtime": 123
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0f48"
#     },
#     "fullplot": "Jim West is a guns-a-blazing former Civil War hero. Artemus Gordon is an inventive U.S. Marshal who excels in disguise. When the United States is threatened by psychotic Confederate Arliss Loveless, President Ulysses Grant teams the duo up to bring him to justice. On a hazard-packed train journey from Washington D.C. to Utah, West and Gordon must combine their skills to best Loveless and his diabolical machines.",
#     "imdb": {
#       "rating": 4.8,
#       "votes": 122655,
#       "id": 120891
#     },
#     "year": 1999,
#     "plot": "The two best hired guns in the West must save President Grant from the clutches of a nineteenth-century inventor-villain.",
#     "genres": [
#       "Action",
#       "Western",
#       "Comedy"
#     ],
#     "rated": "PG-13",
#     "metacritic": 38,
#     "title": "Wild Wild West",
#     "lastupdated": "2015-09-10 17:48:40.287000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Jim Thomas (story)",
#       "John Thomas (story)",
#       "S.S. Wilson (screenplay)",
#       "Brent Maddock (screenplay)",
#       "Jeffrey Price (screenplay)",
#       "Peter S. Seaman (screenplay)"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://wildwildwest.warnerbros.com",
#       "viewer": {
#         "rating": 2.7,
#         "numReviews": 463636,
#         "meter": 28
#       },
#       "dvd": {
#         "$date": 943920000000
#       },
#       "critic": {
#         "rating": 4.1,
#         "numReviews": 130,
#         "meter": 17
#       },
#       "lastUpdated": {
#         "$date": 1442081682000
#       },
#       "consensus": "Bombastic, manic, and largely laugh-free, Wild Wild West is a bizarre misfire in which greater care was lavished upon the special effects than on the script.",
#       "rotten": 108,
#       "production": "Warner Bros. Pictures",
#       "fresh": 22
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BYmYyMTc4YjItMGNhNC00OWQwLWJhMWUtNTdjZDgxMDI5MjE2L2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 2,
#     "released": {
#       "$date": 930700800000
#     },
#     "awards": {
#       "wins": 10,
#       "nominations": 11,
#       "text": "10 wins & 11 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Will Smith",
#       "Kevin Kline",
#       "Kenneth Branagh",
#       "Salma Hayek"
#     ],
#     "directors": [
#       "Barry Sonnenfeld"
#     ],
#     "runtime": 106
#   },
#   {
#     "_id": {
#       "$oid": "573a139bf29313caabcf3c57"
#     },
#     "plot": "Every Friday, the Colonel puts on his only suit and goes to the dock to await a letter announcing the arrival of his pension. But the townsfolk all know that this pension will never come. ...",
#     "genres": [
#       "Drama"
#     ],
#     "runtime": 118,
#     "cast": [
#       "Fernando Luj\u00e8n",
#       "Marisa Paredes",
#       "Salma Hayek",
#       "Rafael Incl\u00e8n"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTQxNjc2Njk1NV5BMl5BanBnXkFtZTcwOTY2MTU1MQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "No One Writes to the Colonel",
#     "fullplot": "Every Friday, the Colonel puts on his only suit and goes to the dock to await a letter announcing the arrival of his pension. But the townsfolk all know that this pension will never come. His wife also knows it, and even he knows it. But he is still waiting, living with the pain of the death of his son.",
#     "languages": [
#       "Spanish"
#     ],
#     "released": {
#       "$date": 928281600000
#     },
#     "directors": [
#       "Arturo Ripstein"
#     ],
#     "writers": [
#       "Paz Alicia Garciadiego",
#       "Gabriel Garc\u00e8a M\u00e8rquez (novel)"
#     ],
#     "awards": {
#       "wins": 1,
#       "nominations": 2,
#       "text": "1 win & 2 nominations."
#     },
#     "lastupdated": "2015-07-30 00:34:51.927000000",
#     "year": 1999,
#     "imdb": {
#       "rating": 6.9,
#       "votes": 821,
#       "id": 132905
#     },
#     "countries": [
#       "Mexico",
#       "France",
#       "Spain"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.3,
#         "numReviews": 1004,
#         "meter": 62
#       },
#       "dvd": {
#         "$date": 1055203200000
#       },
#       "production": "Latin Crush",
#       "lastUpdated": {
#         "$date": 1442085702000
#       }
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a139ef29313caabcfba16"
#     },
#     "fullplot": "An anthology film retelling the story of the famous Studio 54, a hot disco hangout for the social elite of New York. The movie follows several characters at once, some of whom are in desperate straits and on the verge of crashing.",
#     "imdb": {
#       "rating": 5.8,
#       "votes": 26552,
#       "id": 120577
#     },
#     "year": 1998,
#     "plot": "Famous 70s NYC nightclub seen and told through the eyes of a young employee.",
#     "genres": [
#       "Drama",
#       "Music"
#     ],
#     "rated": "R",
#     "metacritic": 33,
#     "title": "54",
#     "lastupdated": "2015-08-30 02:17:08.113000000",
#     "languages": [
#       "English"
#     ],
#     "writers": [
#       "Mark Christopher"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.miramax.com/movie/54",
#       "viewer": {
#         "rating": 2.8,
#         "numReviews": 31237,
#         "meter": 44
#       },
#       "dvd": {
#         "$date": 986256000000
#       },
#       "critic": {
#         "rating": 4.2,
#         "numReviews": 66,
#         "meter": 15
#       },
#       "lastUpdated": {
#         "$date": 1440270591000
#       },
#       "consensus": "Poor plot development and slow pacing keep 54 from capturing the energy of it's legendary namesake.",
#       "rotten": 56,
#       "production": "Miramax Films",
#       "fresh": 10
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BYTIzNzIxMjEtZDNiZS00Y2E1LTkwOTItZGJjOTMwYzU4YzVmXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 1,
#     "released": {
#       "$date": 904262400000
#     },
#     "awards": {
#       "wins": 0,
#       "nominations": 7,
#       "text": "7 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Ryan Phillippe",
#       "Salma Hayek",
#       "Neve Campbell",
#       "Mike Myers"
#     ],
#     "directors": [
#       "Mark Christopher"
#     ],
#     "runtime": 93
#   },
#   {
#     "_id": {
#       "$oid": "573a13a4f29313caabd1276d"
#     },
#     "plot": "In the Time of the Butterflies is inspired by the true story of the three Mirabal sisters who, in 1960, were murdered for their part in an underground plot to overthrow the government.",
#     "genres": [
#       "Crime",
#       "Drama",
#       "History"
#     ],
#     "runtime": 95,
#     "rated": "PG-13",
#     "cast": [
#       "Salma Hayek",
#       "Edward James Olmos",
#       "M\u00e8a Maestro",
#       "Demian Bichir"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTQyNzc0NDExN15BMl5BanBnXkFtZTcwOTYwOTAyMQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "In the Time of the Butterflies",
#     "fullplot": "On November 25, 1960, the bodies of three sisters were found near the bottom of a cliff on the north coast of the Dominican Republic. The official daily 'El Caribe' reports that it had been an accident, but it does not mention that a fourth sister lives. Nor does it mention the sisters' fierce opposition to the General Trujillo's dictatorship. This is their story: how Minerva started the tragedy by refusing Trujillo; how Patria became an opponent from the church itself; how Maria Teresa joined the revolution through the love. And how they lost their wings, but not their courage. They were Las Mariposas - \"The Butterflies\".",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 1092873600000
#     },
#     "directors": [
#       "Mariano Barroso"
#     ],
#     "writers": [
#       "Julia \u00e8lvarez (novel)",
#       "Judy Klass (teleplay)",
#       "David Klass (teleplay)"
#     ],
#     "awards": {
#       "wins": 2,
#       "nominations": 2,
#       "text": "2 wins & 2 nominations."
#     },
#     "lastupdated": "2015-08-28 00:32:45.503000000",
#     "year": 2001,
#     "imdb": {
#       "rating": 6.8,
#       "votes": 1648,
#       "id": 263467
#     },
#     "countries": [
#       "USA",
#       "Mexico"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "viewer": {
#         "rating": 3.8,
#         "numReviews": 3826,
#         "meter": 78
#       },
#       "dvd": {
#         "$date": 1020729600000
#       },
#       "production": "MGM",
#       "lastUpdated": {
#         "$date": 1437504796000
#       }
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a13a6f29313caabd17bd5"
#     },
#     "fullplot": "In the third movie of Rodriguez's \"Mariachi\" trilogy, a Mexican drug lord pretends to overthrow the Mexican government, and is connected to a corrupt CIA agent who at that time, demands retribution from his worst enemy to carry out the drug lord's uprising against the government.",
#     "imdb": {
#       "rating": 6.4,
#       "votes": 122029,
#       "id": 285823
#     },
#     "year": 2003,
#     "plot": "Hitman \"El Mariachi\" becomes involved in international espionage involving a psychotic CIA agent and a corrupt Mexican general.",
#     "genres": [
#       "Action",
#       "Thriller"
#     ],
#     "rated": "R",
#     "metacritic": 56,
#     "title": "Once Upon a Time in Mexico",
#     "lastupdated": "2015-09-07 00:09:02.457000000",
#     "languages": [
#       "English",
#       "Spanish"
#     ],
#     "writers": [
#       "Robert Rodriguez"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.sonypictures.com/movies/onceuponatimeinmexico/",
#       "viewer": {
#         "rating": 3.2,
#         "numReviews": 284917,
#         "meter": 64
#       },
#       "dvd": {
#         "$date": 1074556800000
#       },
#       "critic": {
#         "rating": 6.3,
#         "numReviews": 163,
#         "meter": 68
#       },
#       "boxOffice": "$55.8M",
#       "consensus": "Violent, pulpy, loopy fun, with Depp stealing the show.",
#       "rotten": 52,
#       "production": "Sony Pictures Releasing",
#       "lastUpdated": {
#         "$date": 1442253796000
#       },
#       "fresh": 111
#     },
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTU5MDg5OTcwOV5BMl5BanBnXkFtZTcwMjI1MTIzMw@@._V1_SY1000_SX677_AL_.jpg",
#     "num_mflix_comments": 2,
#     "released": {
#       "$date": 1063324800000
#     },
#     "awards": {
#       "wins": 3,
#       "nominations": 4,
#       "text": "3 wins & 4 nominations."
#     },
#     "countries": [
#       "USA"
#     ],
#     "cast": [
#       "Antonio Banderas",
#       "Salma Hayek",
#       "Johnny Depp",
#       "Mickey Rourke"
#     ],
#     "directors": [
#       "Robert Rodriguez"
#     ],
#     "runtime": 102
#   },
#   {
#     "_id": {
#       "$oid": "573a13adf29313caabd2af88"
#     },
#     "plot": "The story of what happens after a master thief achieves his last big score, when the FBI agent who promised he'd capture him is about to do just that.",
#     "genres": [
#       "Action",
#       "Comedy",
#       "Crime"
#     ],
#     "runtime": 97,
#     "metacritic": 38,
#     "rated": "PG-13",
#     "cast": [
#       "Pierce Brosnan",
#       "Salma Hayek",
#       "Woody Harrelson",
#       "Don Cheadle"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BN2YyMmE1MTUtNTg2OS00ZWRiLWFhZTQtZDViM2MyOGJhZDY3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg",
#     "title": "After the Sunset",
#     "fullplot": "After a successful last score, a master thief retires to an island paradise. His lifelong nemesis, a crafty FBI agent, washes ashore to ensure he's making good on his promise. The pair soon enters into a new game of cat-and-mouse.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 1100217600000
#     },
#     "directors": [
#       "Brett Ratner"
#     ],
#     "writers": [
#       "Paul Zbyszewski (story)",
#       "Paul Zbyszewski (screenplay)",
#       "Craig Rosenberg (screenplay)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-08-21 00:50:02.187000000",
#     "year": 2004,
#     "imdb": {
#       "rating": 6.3,
#       "votes": 36636,
#       "id": 367479
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie"
#   },
#   {
#     "_id": {
#       "$oid": "573a13aff29313caabd2f0a5"
#     },
#     "plot": "Mexican beauty Camilla hopes to rise above her station by marrying a wealthy American. That is complicated by meeting Arturo Bandini, a first-generation Italian hoping to land a writing career and a blue-eyed blonde on his arm.",
#     "genres": [
#       "Drama",
#       "Romance"
#     ],
#     "runtime": 117,
#     "metacritic": 58,
#     "rated": "R",
#     "cast": [
#       "Colin Farrell",
#       "Salma Hayek",
#       "Donald Sutherland",
#       "Eileen Atkins"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BZDc0ZWFmYjAtMTc2ZS00MzdlLThkZjAtM2I5ZGZlZjYzZDRlXkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Ask the Dust",
#     "fullplot": "L.A. in the early 1930's: racism, poverty, and disease color the Bunker Hill neighborhood where Arturo Bandini, a lover of men and beasts alike, has arrived from Colorado to write the great Los Angeles novel. After six months and down to his last nickel, he orders a cup of coffee, served by Camilla Lopez, beautiful, self-possessed, and Mexican. Arturo gets advice, encouragement, and an occasional check from H.L. Mencken, so he keeps writing and he keeps seeing Camilla. But, he's mean to her for no apparent reason, so the relationship sputters. A housekeeper from back East suggests a way out of his jealously and fears. \"Camilla Bandini\": is it in the cards?",
#     "languages": [
#       "English",
#       "Spanish"
#     ],
#     "released": {
#       "$date": 1144886400000
#     },
#     "directors": [
#       "Robert Towne"
#     ],
#     "writers": [
#       "Robert Towne (screenplay)",
#       "John Fante (novel)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-08-14 01:31:42.053000000",
#     "year": 2006,
#     "imdb": {
#       "rating": 5.8,
#       "votes": 7690,
#       "id": 384814
#     },
#     "countries": [
#       "USA",
#       "Germany"
#     ],
#     "type": "movie"
#   },
#   {
#     "_id": {
#       "$oid": "573a13b3f29313caabd3c2c0"
#     },
#     "plot": "Based on the true story, two homicide detectives track Martha Beck and Raymond Martinez Fernandez, a murderous pair known as the \"Lonely Hearts Killers\" who lured their victims through the personals.",
#     "genres": [
#       "Crime",
#       "Drama",
#       "Romance"
#     ],
#     "runtime": 108,
#     "metacritic": 60,
#     "rated": "R",
#     "cast": [
#       "John Travolta",
#       "James Gandolfini",
#       "Jared Leto",
#       "Salma Hayek"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BYTIxNGNjZTMtMGM5Ny00MmQ5LWEwODQtYTZkNGY2MjQ1MGM3XkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Lonely Hearts",
#     "fullplot": "In the late 1940's, Martha Beck and Raymond Fernandez were America's notorious \"Lonely Hearts Killers\". Their lethal scam was simple; they would swindle and then viciously murder lovelorn war widows who would answer their personal ads in which Ray would describe himself as a sexy Latin Lover. Ironically, Ray's initial introduction to Martha was as a prospective mark. But when they met, it was love at first sight, perhaps as a result of their penchant for kinky sex and their mutual love for duplicity and easy money. With Martha posing as Ray's sister, they bilked elderly spinsters and widows of their savings and then viciously murdered them in a bloodbath of sexual frenzy. When they were arrested, Martha and Ray confessed to 12 killings, although it is believed the actual number is closer to 20. At their sensational trial, Martha and Ray cooed, held hands and seemed as though they could not get enough of each other. Their plea of not guilty by reason of insanity was rejected, and on August 22, 1949, the homicidal lovers were sentenced to death. After numerous appeals, they were electrocuted on March 8, 1951, side-by-side in Sing Sing prison.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 1161388800000
#     },
#     "directors": [
#       "Todd Robinson"
#     ],
#     "writers": [
#       "Todd Robinson"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 1,
#       "text": "1 nomination."
#     },
#     "lastupdated": "2015-08-28 00:31:01.910000000",
#     "year": 2006,
#     "imdb": {
#       "rating": 6.5,
#       "votes": 16744,
#       "id": 441774
#     },
#     "countries": [
#       "Germany",
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.cstar.com/lonelyhearts/",
#       "viewer": {
#         "rating": 3.2,
#         "numReviews": 9726,
#         "meter": 49
#       },
#       "dvd": {
#         "$date": 1185840000000
#       },
#       "critic": {
#         "rating": 5.6,
#         "numReviews": 42,
#         "meter": 48
#       },
#       "boxOffice": "$0.1M",
#       "consensus": "Several genres and plotlines intertwine in Lonely Hearts but don't connect, creating an uneven and unsatisfying film.",
#       "rotten": 22,
#       "production": "Samuel Goldwyn/Roadside",
#       "lastUpdated": {
#         "$date": 1440011573000
#       },
#       "fresh": 20
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a13b3f29313caabd3dccc"
#     },
#     "plot": "The events leading up to the sword fighting cat's meeting with Shrek and his friends.",
#     "genres": [
#       "Animation",
#       "Adventure",
#       "Comedy"
#     ],
#     "runtime": 90,
#     "metacritic": 65,
#     "rated": "PG",
#     "cast": [
#       "Antonio Banderas",
#       "Salma Hayek",
#       "Zach Galifianakis",
#       "Billy Bob Thornton"
#     ],
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTMxMTU5MTY4MV5BMl5BanBnXkFtZTcwNzgyNjg2NQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Puss in Boots",
#     "fullplot": "Years before meeting Shrek and Donkey, the adorable but tricky Puss in Boots must clear his name from all charges making him a wanted fugitive. While trying to steal magic beans from the infamous criminals Jack and Jill, the hero crosses paths with his female match, Kitty Softpaws, who leads Puss to his old friend, but now enemy, Humpty Dumpty. Memories of friendship and betrayal enlarges Puss' doubt, but he eventually agrees to help the egg get the magic beans. Together, the three plan to steal the beans, get to the Giant's castle, nab the golden goose, and clear Puss' name.",
#     "languages": [
#       "English",
#       "Spanish"
#     ],
#     "released": {
#       "$date": 1319760000000
#     },
#     "directors": [
#       "Chris Miller"
#     ],
#     "writers": [
#       "Charles Perrault (character)",
#       "Tom Wheeler (screenplay)",
#       "Brian Lynch (story)",
#       "William Davies (story)",
#       "Tom Wheeler (story)"
#     ],
#     "awards": {
#       "wins": 7,
#       "nominations": 41,
#       "text": "Nominated for 1 Oscar. Another 6 wins & 41 nominations."
#     },
#     "lastupdated": "2015-08-23 00:38:10.813000000",
#     "year": 2011,
#     "imdb": {
#       "rating": 6.7,
#       "votes": 104860,
#       "id": 448694
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.pussinbootsthemovie.com/",
#       "viewer": {
#         "rating": 3.6,
#         "numReviews": 77938,
#         "meter": 68
#       },
#       "dvd": {
#         "$date": 1330041600000
#       },
#       "critic": {
#         "rating": 6.8,
#         "numReviews": 142,
#         "meter": 84
#       },
#       "boxOffice": "$149.2M",
#       "consensus": "It isn't deep or groundbreaking, but what it lacks in profundity, Puss in Boots more than makes up for with an abundance of wit, visual sparkle, and effervescent charm.",
#       "rotten": 23,
#       "production": "Paramount/Dreamworks",
#       "lastUpdated": {
#         "$date": 1442081977000
#       },
#       "fresh": 119
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a13ccf29313caabd82d05"
#     },
#     "plot": "Exiled artist and poet Mustafa embarks on a journey home with his housekeeper and her daughter; together the trio must evade the authorities who fear that the truth in Mustafa's words will incite rebellion.",
#     "genres": [
#       "Animation"
#     ],
#     "runtime": 84,
#     "metacritic": 61,
#     "rated": "PG",
#     "cast": [
#       "Salma Hayek",
#       "Liam Neeson",
#       "John Krasinski",
#       "Quvenzhan\u00e8 Wallis"
#     ],
#     "num_mflix_comments": 5,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTY5NzI4MjE2OV5BMl5BanBnXkFtZTgwMDg3OTU5NTE@._V1_SY1000_SX677_AL_.jpg",
#     "title": "The Prophet",
#     "fullplot": "Exiled artist and poet Mustafa embarks on a journey home with his housekeeper and her daughter; together the trio must evade the authorities who fear that the truth in Mustafa's words will incite rebellion.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 1438905600000
#     },
#     "directors": [
#       "Roger Allers",
#       "Ga\u00e8tan Brizzi",
#       "Paul Brizzi",
#       "Joan C. Gratz",
#       "Mohammed Saeed Harib",
#       "Tomm Moore",
#       "Nina Paley",
#       "Bill Plympton",
#       "Joann Sfar",
#       "Michal Socha"
#     ],
#     "writers": [
#       "Roger Allers (screenplay)",
#       "Kahlil Gibran (novel)",
#       "Irene Mecchi (Additional Story & Dialogue)",
#       "Hanna Weg (additional writing)",
#       "Douglas Wood (additional story and dialogue)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 2,
#       "text": "2 nominations."
#     },
#     "lastupdated": "2015-08-29 00:02:18.623000000",
#     "year": 2014,
#     "imdb": {
#       "rating": 6.8,
#       "votes": 618,
#       "id": 1640718
#     },
#     "countries": [
#       "USA",
#       "France",
#       "Canada",
#       "Lebanon",
#       "Qatar"
#     ],
#     "type": "movie"
#   },
#   {
#     "_id": {
#       "$oid": "573a13ccf29313caabd833ed"
#     },
#     "plot": "A high school biology teacher looks to become a successful mixed-martial arts fighter in an effort to raise money to prevent extra-curricular activities from being axed at his cash-strapped school.",
#     "genres": [
#       "Action",
#       "Comedy",
#       "Sport"
#     ],
#     "runtime": 105,
#     "metacritic": 40,
#     "rated": "PG",
#     "cast": [
#       "Kevin James",
#       "Salma Hayek",
#       "Henry Winkler",
#       "Greg Germann"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTUxMzEzNDQ0Nl5BMl5BanBnXkFtZTcwMDI2NTY1OA@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Here Comes the Boom",
#     "fullplot": "A high school biology teacher looks to become a successful mixed-martial arts fighter in an effort to raise money to prevent extra-curricular activities from being axed at his cash-strapped school.",
#     "languages": [
#       "English",
#       "Dutch"
#     ],
#     "released": {
#       "$date": 1350000000000
#     },
#     "directors": [
#       "Frank Coraci"
#     ],
#     "writers": [
#       "Allan Loeb",
#       "Kevin James"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 3,
#       "text": "3 nominations."
#     },
#     "lastupdated": "2015-09-05 00:38:20.260000000",
#     "year": 2012,
#     "imdb": {
#       "rating": 6.5,
#       "votes": 69939,
#       "id": 1648179
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie"
#   },
#   {
#     "_id": {
#       "$oid": "573a13cff29313caabd88de0"
#     },
#     "plot": "A high school biology teacher looks to become a successful mixed-martial arts fighter in an effort to raise money to prevent extra-curricular activities from being axed at his cash-strapped school.",
#     "genres": [
#       "Action",
#       "Comedy",
#       "Sport"
#     ],
#     "runtime": 105,
#     "metacritic": 40,
#     "rated": "PG",
#     "cast": [
#       "Kevin James",
#       "Salma Hayek",
#       "Henry Winkler",
#       "Greg Germann"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BMTUxMzEzNDQ0Nl5BMl5BanBnXkFtZTcwMDI2NTY1OA@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Here Comes the Boom",
#     "fullplot": "A high school biology teacher looks to become a successful mixed-martial arts fighter in an effort to raise money to prevent extra-curricular activities from being axed at his cash-strapped school.",
#     "languages": [
#       "English",
#       "Dutch"
#     ],
#     "released": {
#       "$date": 1350000000000
#     },
#     "directors": [
#       "Frank Coraci"
#     ],
#     "writers": [
#       "Allan Loeb",
#       "Kevin James"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 3,
#       "text": "3 nominations."
#     },
#     "lastupdated": "2015-09-12 06:11:27.110000000",
#     "year": 2012,
#     "imdb": {
#       "rating": 6.5,
#       "votes": 70090,
#       "id": 1648179
#     },
#     "countries": [
#       "USA"
#     ],
#     "type": "movie"
#   },
#   {
#     "_id": {
#       "$oid": "573a13d1f29313caabd8ec00"
#     },
#     "plot": "An out-of-work publicist who suffers an accident looks to sell the exclusive interview rights to the highest bidder in an attempt to provide for his family.",
#     "genres": [
#       "Drama"
#     ],
#     "runtime": 94,
#     "metacritic": 32,
#     "cast": [
#       "Jos\u00e8 Mota",
#       "Salma Hayek",
#       "Blanca Portillo",
#       "Juan Luis Galiardo"
#     ],
#     "num_mflix_comments": 2,
#     "poster": "https://m.media-amazon.com/images/M/MV5BNzY4NTEyMjMzOF5BMl5BanBnXkFtZTcwNjEzNzIwOQ@@._V1_SY1000_SX677_AL_.jpg",
#     "title": "As Luck Would Have It",
#     "fullplot": "An out-of-work publicist who suffers an accident looks to sell the exclusive interview rights to the highest bidder in an attempt to provide for his family.",
#     "languages": [
#       "Spanish"
#     ],
#     "released": {
#       "$date": 1326412800000
#     },
#     "directors": [
#       "\u00e8lex de la Iglesia"
#     ],
#     "writers": [
#       "Randy Feldman (screenplay)"
#     ],
#     "awards": {
#       "wins": 0,
#       "nominations": 3,
#       "text": "3 nominations."
#     },
#     "lastupdated": "2015-08-08 00:39:36.037000000",
#     "year": 2011,
#     "imdb": {
#       "rating": 6.2,
#       "votes": 1786,
#       "id": 1808240
#     },
#     "countries": [
#       "Spain",
#       "France",
#       "USA"
#     ],
#     "type": "movie",
#     "tomatoes": {
#       "website": "http://www.ifcfilms.com/films/as-luck-would-have-it",
#       "viewer": {
#         "rating": 3.2,
#         "numReviews": 302,
#         "meter": 48
#       },
#       "critic": {
#         "rating": 4.6,
#         "numReviews": 5,
#         "meter": 40
#       },
#       "lastUpdated": {
#         "$date": 1434391346000
#       },
#       "rotten": 3,
#       "production": "Independent Pictures",
#       "fresh": 2
#     }
#   },
#   {
#     "_id": {
#       "$oid": "573a13e9f29313caabdcc159"
#     },
#     "plot": "The film serves as Garrone's English-language debut and will interweave three separate story strands bookended by brief bits in which Italians Alba Rohrwacher and Massimo Ceccherini will ...",
#     "genres": [
#       "Fantasy",
#       "Romance"
#     ],
#     "runtime": 125,
#     "metacritic": 80,
#     "cast": [
#       "Salma Hayek",
#       "Vincent Cassel",
#       "Toby Jones",
#       "John C. Reilly"
#     ],
#     "num_mflix_comments": 1,
#     "poster": "https://m.media-amazon.com/images/M/MV5BOTBiY2U2MTctNTA4Ni00MDBkLTk5MjItZWUxNDk5YmFlMTliL2ltYWdlXkEyXkFqcGdeQXVyNDUxNjc5NjY@._V1_SY1000_SX677_AL_.jpg",
#     "title": "Tale of Tales",
#     "fullplot": "The film serves as Garrone's English-language debut and will interweave three separate story strands bookended by brief bits in which Italians Alba Rohrwacher and Massimo Ceccherini will play a street circus family. In one tale Salma Hayek will play a jealous queen who forfeits her husband's life. In another, Vincent Cassel plays a king whose passion is stoked by two mysterious sisters.",
#     "languages": [
#       "English"
#     ],
#     "released": {
#       "$date": 1431561600000
#     },
#     "directors": [
#       "Matteo Garrone"
#     ],
#     "writers": [
#       "Giambattista Basile (book)",
#       "Edoardo Albinati (screenplay)",
#       "Ugo Chiti (screenplay)",
#       "Matteo Garrone (screenplay)",
#       "Massimo Gaudioso (screenplay)"
#     ],
#     "awards": {
#       "wins": 3,
#       "nominations": 4,
#       "text": "3 wins & 4 nominations."
#     },
#     "lastupdated": "2015-09-01 00:07:19.663000000",
#     "year": 2015,
#     "imdb": {
#       "rating": 6.7,
#       "votes": 1961,
#       "id": 3278330
#     },
#     "countries": [
#       "Italy",
#       "France",
#       "UK"
#     ],
#     "type": "movie"
#   }
# ]

# %%
# find all movies with Salma Hayek, but only project the "_id" and "title" fields
cursor = movies.find( { "cast": "Salma Hayek" }, { "title": 1 } )
print(dumps(cursor, indent=2))
# Out:
# [
#   {
#     "_id": {
#       "$oid": "573a1399f29313caabceea6d"
#     },
#     "title": "Roadracers"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcef0b6"
#     },
#     "title": "Midaq Alley"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcef179"
#     },
#     "title": "Desperado"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf092d"
#     },
#     "title": "Fools Rush In"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf09f1"
#     },
#     "title": "The Hunchback"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0e4f"
#     },
#     "title": "54"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0ea6"
#     },
#     "title": "Frida"
#   },
#   {
#     "_id": {
#       "$oid": "573a139af29313caabcf0f48"
#     },
#     "title": "Wild Wild West"
#   },
#   {
#     "_id": {
#       "$oid": "573a139bf29313caabcf3c57"
#     },
#     "title": "No One Writes to the Colonel"
#   },
#   {
#     "_id": {
#       "$oid": "573a139ef29313caabcfba16"
#     },
#     "title": "54"
#   },
#   {
#     "_id": {
#       "$oid": "573a13a4f29313caabd1276d"
#     },
#     "title": "In the Time of the Butterflies"
#   },
#   {
#     "_id": {
#       "$oid": "573a13a6f29313caabd17bd5"
#     },
#     "title": "Once Upon a Time in Mexico"
#   },
#   {
#     "_id": {
#       "$oid": "573a13adf29313caabd2af88"
#     },
#     "title": "After the Sunset"
#   },
#   {
#     "_id": {
#       "$oid": "573a13aff29313caabd2f0a5"
#     },
#     "title": "Ask the Dust"
#   },
#   {
#     "_id": {
#       "$oid": "573a13b3f29313caabd3c2c0"
#     },
#     "title": "Lonely Hearts"
#   },
#   {
#     "_id": {
#       "$oid": "573a13b3f29313caabd3dccc"
#     },
#     "title": "Puss in Boots"
#   },
#   {
#     "_id": {
#       "$oid": "573a13ccf29313caabd82d05"
#     },
#     "title": "The Prophet"
#   },
#   {
#     "_id": {
#       "$oid": "573a13ccf29313caabd833ed"
#     },
#     "title": "Here Comes the Boom"
#   },
#   {
#     "_id": {
#       "$oid": "573a13cff29313caabd88de0"
#     },
#     "title": "Here Comes the Boom"
#   },
#   {
#     "_id": {
#       "$oid": "573a13d1f29313caabd8ec00"
#     },
#     "title": "As Luck Would Have It"
#   },
#   {
#     "_id": {
#       "$oid": "573a13e9f29313caabdcc159"
#     },
#     "title": "Tale of Tales"
#   }
# ]

# %%
# find all movies with Salma Hayek, but only project the "title" field
cursor = movies.find( { "countries": ["Brazil"] }, { "title": 1, "_id": 0 } )
print(list(cursor))
# print(dumps(cursor, indent=2))
# Out:
# [{'title': 'The Hustlers'}, {'title': 'The Given Word'}, {'title': 'Barren Lives'}, {'title': 'Black God, White Devil'}, {'title': 'The Deceased'}, {'title': 'Entranced Earth'}, {'title': 'Macunaima'}, {'title': 'How Tasty Was My Little Frenchman'}, {'title': 'Prata Palomares'}, {'title': 'O Amuleto de Ogum'}, {'title': 'Dona Flor and Her Two Husbands'}, {'title': 'Lucio Flavio'}, {'title': 'The Age of the Earth'}, {'title': 'Pixote'}, {'title': 'Hour of the Star'}, {'title': 'Isle of Flowers'}, {'title': 'O Quatrilho'}, {'title': 'Baile Perfumado'}, {'title': 'Twenty Years Later'}, {'title': 'Besame Mucho'}, {'title': 'The Red Light Bandit'}, {'title': 'Orfeu'}, {'title': 'Eros'}, {'title': 'Olga'}, {'title': 'Blablablè'}, {'title': 'To the Left of the Father'}, {'title': 'Me You Them'}, {'title': 'Barrela: Escola de Crimes'}, {'title': 'Brainstorm'}, {'title': 'Tainah, an Amazon Adventure'}, {'title': "A Dog's Will"}, {'title': 'Possible Loves'}, {'title': 'Maids'}, {'title': 'Desmundo'}, {'title': 'Days of Nietzsche in Turin'}, {'title': 'The Man of the Year'}, {'title': "Cazuza: Time Doesn't Stop"}, {'title': "Cazuza: Time Doesn't Stop"}, {'title': 'Something in the Air'}, {'title': 'Edifècio Master'}, {'title': 'Bus 174'}, {'title': 'God Is Brazilian'}, {'title': 'So Normal'}, {'title': "Wood & Stock: Sexo, Orègano e Rock'n'Roll"}, {'title': 'The Man Who Copied'}, {'title': 'Lisbela and the Prisoner'}, {'title': 'A Love Movie'}, {'title': 'House of Sand'}, {'title': 'The Middle of the World'}, {'title': 'A Alma do Osso'}, {'title': 'Meu Tio Matou um Cara'}, {'title': 'èrido Movie'}, {'title': '2 Filhos de Francisco: A Histèria de Zezè di Camargo & Luciano'}, {'title': 'If I Were You'}, {'title': 'Party Crashers'}, {'title': 'O Coronel e o Lobisomem'}, {'title': 'House of Sand'}, {'title': 'Mais Uma Vez Amor'}, {'title': 'The Machine'}, {'title': 'Batismo de Sangue'}, {'title': 'Zuzu Angel'}, {'title': 'Drained'}, {'title': 'I Remember'}, {'title': 'Linha de Passe'}, {'title': 'Angels of the Sun'}, {'title': 'Angels of the Sun'}, {'title': 'The Year My Parents Went on Vacation'}, {'title': 'Elite Squad'}, {'title': 'City of Men'}, {'title': 'City of Men'}, {'title': 'Camila Jam'}, {'title': 'Romance'}, {'title': 'è Paè, è'}, {'title': 'Saneamento Bèsico, O Filme'}, {'title': 'Embodiment of Evil'}, {'title': 'O Homem Que Desafiou o Diabo'}, {'title': 'Chega de Saudade'}, {'title': 'A Grande Famèlia: O Filme'}, {'title': 'Santiago'}, {'title': 'Adrift'}, {'title': 'Cèo Sem Dono'}, {'title': 'Cartola - Mèsica Para os Olhos'}, {'title': 'The Best Things in the World'}, {'title': 'The Milky Way'}, {'title': 'Elvis & Madona'}, {'title': 'If I Were You 2'}, {'title': 'Playing'}, {'title': 'Cafè com Leite'}, {'title': 'Buddies'}, {'title': 'Bellini and the Devil'}, {'title': 'Time of Peace'}, {'title': 'Chico Xavier'}, {'title': 'A Mulher Invisèvel'}, {'title': 'The Herb of the Rat'}, {'title': 'In Therapy'}, {'title': 'Between the Sheets'}, {'title': 'Pro Dia Nascer Feliz'}, {'title': 'The Assailant'}, {'title': 'The Story of Me'}, {'title': 'Titès - A Vida Atè Parece uma Festa'}, {'title': "That's It"}, {'title': 'Reflexèes de um Liquidificador'}, {'title': 'Astral City: A Spiritual Journey'}, {'title': 'I Travel Because I Have to, I Come Back Because I Love You'}, {'title': 'Loki - Arnaldo Baptista'}, {'title': 'Natimorto'}, {'title': 'Elite Squad: The Enemy Within'}, {'title': 'Head Over Heels'}, {'title': 'Federal Bank Heist'}, {'title': 'Little Surfer Girl'}, {'title': 'Hard Labor'}, {'title': "I Don't Want to Go Back Alone"}, {'title': 'The Way He Looks'}, {'title': 'Heleno'}, {'title': 'So Hard to Forget'}, {'title': 'Two Rabbits'}, {'title': 'Boca'}, {'title': 'Brazilian Western'}, {'title': 'The Clown'}, {'title': 'Rènia'}, {'title': 'The Man from the Future'}, {'title': 'Mato Sem Cachorro'}, {'title': 'Artificial Paradises'}, {'title': 'Amor?'}, {'title': "Father's Chair"}, {'title': 'Xingu'}, {'title': 'Southwest'}, {' ...

# %%
db = mflix.movies
list(db.find( { "countries" : { "$in" : ['Brazil'] } }, { "title" : 1 } ))
# Out:
# [{'_id': ObjectId('573a1394f29313caabce102f'), 'title': 'Black Orpheus'},
#  {'_id': ObjectId('573a1395f29313caabce1a81'), 'title': 'The Hustlers'},
#  {'_id': ObjectId('573a1395f29313caabce1c6c'), 'title': 'The Given Word'},
#  {'_id': ObjectId('573a1395f29313caabce2192'), 'title': 'Barren Lives'},
#  {'_id': ObjectId('573a1395f29313caabce22dd'),
#   'title': 'Black God, White Devil'},
#  {'_id': ObjectId('573a1395f29313caabce234e'), 'title': 'The Guns'},
#  {'_id': ObjectId('573a1395f29313caabce2747'), 'title': 'The Deceased'},
#  {'_id': ObjectId('573a1395f29313caabce3329'), 'title': 'Entranced Earth'},
#  {'_id': ObjectId('573a1396f29313caabce3a40'), 'title': 'Antonio das Mortes'},
#  {'_id': ObjectId('573a1396f29313caabce3b9f'), 'title': 'Macunaima'},
#  {'_id': ObjectId('573a1396f29313caabce443b'),
#   'title': 'How Tasty Was My Little Frenchman'},
#  {'_id': ObjectId('573a1396f29313caabce4c66'), 'title': 'Prata Palomares'},
#  {'_id': ObjectId('573a1396f29313caabce53ea'), 'title': 'O Amuleto de Ogum'},
#  {'_id': ObjectId('573a1397f29313caabce6b98'),
#   'title': 'Dona Flor and Her Two Husbands'},
#  {'_id': ObjectId('573a1397f29313caabce6d3e'), 'title': 'Lucio Flavio'},
#  {'_id': ObjectId('573a1397f29313caabce771a'), 'title': 'Bye Bye Brasil'},
#  {'_id': ObjectId('573a1397f29313caabce78d3'),
#   'title': 'The Age of the Earth'},
#  {'_id': ObjectId('573a1397f29313caabce8060'), 'title': 'Pixote'},
#  {'_id': ObjectId('573a1398f29313caabce9893'), 'title': 'Hour of the Star'},
#  {'_id': ObjectId('573a1398f29313caabce98ff'),
#   'title': 'Kiss of the Spider Woman'},
#  {'_id': ObjectId('573a1398f29313caabceb790'), 'title': 'Isle of Flowers'},
#  {'_id': ObjectId('573a1399f29313caabcec5e9'),
#   'title': 'At Play in the Fields of the Lord'},
#  {'_id': ObjectId('573a1399f29313caabceceb4'), 'title': 'Amazon'},
#  {'_id': ObjectId('573a1399f29313caabcee458'),
#   'title': 'Carmen Miranda: Bananas Is My Business'},
#  {'_id': ObjectId('573a1399f29313caabceec11'),
#   'title': 'Tigrero: A Film That Was Never Made'},
#  {'_id': ObjectId('573a139af29313caabcef6b7'), 'title': 'O Quatrilho'},
#  {'_id': ObjectId('573a139af29313caabcef85f'), 'title': 'Foreign Land'},
#  {'_id': ObjectId('573a139af29313caabcf0761'), 'title': 'Anaconda'},
#  {'_id': ObjectId('573a139af29313caabcf0771'), 'title': 'Baile Perfumado'},
#  {'_id': ObjectId('573a139af29313caabcf0ba0'),
#   'title': 'Four Days in September'},
#  {'_id': ObjectId('573a139bf29313caabcf25df'),
#   'title': 'Iracema - Uma Transa Amazènica'},
#  {'_id': ObjectId('573a139bf29313caabcf4212'), 'title': 'Twenty Years Later'},
#  {'_id': ObjectId('573a139cf29313caabcf56bd'), 'title': 'Besame Mucho'},
#  {'_id': ObjectId('573a139cf29313caabcf5a57'), 'title': 'Central Station'},
#  {'_id': ObjectId('573a139cf29313caabcf6903'),
#   'title': 'The Red Light Bandit'},
#  {'_id': ObjectId('573a139ef29313caabcfbb60'), 'title': 'Posthumous Memories'},
#  {'_id': ObjectId('573a139ef29313caabcfbb6b'), 'title': 'Midnight'},
#  {'_id': ObjectId('573a139ef29313caabcff0a1'), 'title': 'Bossa Nova'},
#  {'_id': ObjectId('573a139ff29313caabcffb16'), 'title': 'Orfeu'},
#  {'_id': ObjectId('573a139ff29313caabd0126e'), 'title': 'Eros'},
#  {'_id': ObjectId('573a13a0f29313caabd02cbc'), 'title': 'Olga'},
#  {'_id': ObjectId('573a13a0f29313caabd06041'), 'title': 'Blablablè'},
#  {'_id': ObjectId('573a13a0f29313caabd061be'), 'title': 'The Forest'},
#  {'_id': ObjectId('573a13a3f29313caabd0d562'),
#   'title': 'To the Left of the Father'},
#  {'_id': ObjectId('573a13a3f29313caabd0dff9'), 'title': 'Me You Them'},
#  {'_id': ObjectId('573a13a3f29313caabd0e1c1'),
#   'title': 'Barrela: Escola de Crimes'},
#  {'_id': ObjectId('573a13a4f29313caabd1261d'), 'title': 'Brainstorm'},
#  {'_id': ObjectId('573a13a4f29313caabd129ca'),
#   'title': 'Tainah, an Amazon Adventure'},
#  {'_id': ObjectId('573a13a5f29313caabd14579'), 'title': "A Dog's Will"},
#  {'_id': ObjectId('573a13a5f29313caabd1568e'), 'title': 'Possible Loves'},
#  {'_id': ObjectId('573a13a6f29313caabd16533'), 'title': 'Maids'},
#  {'_id': ObjectId('573a13a6f29313caabd18b4c'), 'title': 'Fear X'},
#  {'_id': ObjectId('573a13a6f29313caabd18f1f'), 'title': 'Behind the Sun'},
#  {'_id': ObjectId('573a13a6f29313caabd196d3'), 'title': 'Carandiru'},
#  {'_id': ObjectId('573a13a6f29313caabd19731'), 'title': 'Desmundo'},
#  {'_id': ObjectId('573a13a7f29313caabd1a294'),
#   'title': 'News from a Personal War'},
#  {'_id': ObjectId('573a13a7f29313caabd1a906'),
#   'title': 'Days of Nietzsche in Turin'},
#  {'_id': ObjectId('573a13a8f29313caabd1e0ca'), 'title': 'The Man of the Year'},
#  {'_id': ObjectId('573a13a9f29313caabd1f1c8'), 'title': 'City of God'},
#  {'_id': ObjectId('573a13a9f29313caabd1f431'), 'title': 'Madame Satè'},
#  {'_id': ObjectId('573a13a9f29313caabd1f631'),
#   'title': 'The Motorcycle Diaries'},
#  {'_id': ObjectId('573a13a9f29313caabd1f6b1'),
#   'title': "Cazuza: Time Doesn't Stop"},
#  {'_id': ObjectId('573a13a9f29313caabd1f9a9'),
#   'title': "Cazuza: Time Doesn't Stop"},
#  {'_id': ObjectId('573a13aaf29313caabd21736'),
#   'title': 'Something in the Air'},
#  {'_id': ObjectId('573a13aaf29313caabd21741'), 'title': 'The Three Marias'},
#  {'_id': ObjectId('573a13aaf29313caabd22eb6'), 'title': 'Edifècio Master'},
#  {'_id': ObjectId('573a13abf29313caabd23f34'), 'title': 'On the Road'},
#  {'_id': ObjectId('573a13abf29313caabd24994'), 'title': 'Bus 174'},
#  {'_id': ObjectId('573a13acf29313caabd270a6'), 'title': 'God Is Brazilian'},
#  {'_id': ObjectId('573a13acf29313caabd2732e'), 'title': 'So Normal'},
#  {'_id': ObjectId('573a13acf29313caabd28526'),
#   'title': "Wood & Stock: Sexo, Orègano e Rock'n'Roll"},
#  {'_id': ObjectId('573a13acf29313caabd290c3'), 'title': 'Rolling Family'},
#  {'_id': ObjectId('573a13adf29313caabd2b0e3'), 'title': 'The Man Who Copied'},
#  {'_id': ObjectId('573a13adf29313caabd2b14f'),
#   'title': 'Lisbela and the Prisoner'},
#  {'_id': ObjectId('573a13adf29313caabd2b443'), 'title': 'A Love Movie'},
#  {'_id': ObjectId('573a13aef29313caabd2c6f2'), 'title': 'House of Sand'},
#  {'_id': ObjectId('573a13aef29313caabd2db89'),
#   'title': 'The Middle of the World'},
#  {'_id': ObjectId('573a13aef29313caabd2e720'), 'title': 'Rosario Tijeras'},
#  {'_id': ObjectId('573a13b0f29313caabd32e71'), 'title': 'Only God Knows'},
#  {'_id': ObjectId('573a13b0f29313caabd33a5f'), 'title': 'A Alma do Osso'},
#  {'_id': ObjectId('573a13b1f29313caabd36527'),
#   'title': 'Meu Tio Matou um Cara'},
#  {'_id': ObjectId('573a13b2f29313caabd39c6b'), 'title': 'èrido Movie'},
#  {'_id': ObjectId('573a13b3f29313caabd3ba4a'),
#   'title': '2 Filhos de Francisco: A Histèria de Zezè di Camargo & Luciano'},
#  {'_id': ObjectId('573a13b3f29313caabd3bd45'), 'title': 'O Diabo a Quatro'},
#  {'_id': ObjectId('573a13b3f29313caabd3dd9e'), 'title': 'If I Were You'},
#  {'_id': ObjectId('573a13b3f29313caabd3ebc7'), 'title': 'Party Crashers'},
#  {'_id': ObjectId('573a13b4f29313caabd3f8b6'),
#   'title': 'O Coronel e o Lobisomem'},
#  {'_id': ObjectId('573a13b4f29313caabd3fb91'), 'title': 'House of Sand'},
#  {'_id': ObjectId('573a13b4f29313caabd3fba9'), 'title': 'Lower City'},
#  {'_id': ObjectId('573a13b4f29313caabd3fc3c'), 'title': 'Mais Uma Vez Amor'},
#  {'_id': ObjectId('573a13b4f29313caabd3fc66'), 'title': 'The Machine'},
#  {'_id': ObjectId('573a13b5f29313caabd439db'), 'title': 'On the Road'},
#  {'_id': ObjectId('573a13b5f29313caabd44e2a'), 'title': 'Batismo de Sangue'},
#  {'_id': ObjectId('573a13b5f29313caabd45682'), 'title': 'Zuzu Angel'},
#  {'_id': ObjectId('573a13b6f29313caabd45cb5'), 'title': "The Pope's Toilet"},
#  {'_id': ObjectId('573a13b6f29313caabd4756d'), 'title': 'Drained'},
#  {'_id': ObjectId('573a13b6f29313caabd4827a'), 'title': 'I Remember'},
#  {'_id': ObjectId('573a13b7f29313caabd4a855'), 'title': 'Samsara'},
#  {'_id': ObjectId('573a13b8f29313caabd4c9fd'), 'title': 'Linha de Passe'},
#  {'_id': ObjectId('573a13b9f29313caabd4eac9'),
#   'title': 'The Mystery of Sintra'},
#  {'_id': ObjectId('573a13baf29313caabd5055f'), 'title': 'Angels of the Sun'},
#  {'_id': ObjectId('573a13baf29313caabd50815'), 'title': 'Mutum'},
#  {'_id': ObjectId('573a13baf29313caabd50858'), 'title': 'Angels of the Sun'},
#  {'_id': ObjectId('573a13baf29313caabd51088'),
#   'title': 'The Year My Parents Went on Vacation'},
#  {'_id': ObjectId('573a13baf29313caabd51317'), 'title': 'Blindness'},
#  {'_id': ObjectId('573a13baf29313caabd51370'), 'title': 'Elite Squad'},
#  {'_id': ObjectId('573a13baf29313caabd51b4c'), 'title': 'City of Men'},
#  {'_id': ObjectId('573a13baf29313caabd51bf9'), 'title': 'City of Men'},
#  {'_id': ObjectId('573a13bbf29313caabd526e4'), 'title': 'Camila Jam'},
#  {'_id': ObjectId('573a13bbf29313caabd5280f'), 'title': 'Romance'},
#  {'_id': ObjectId('573a13bbf29313caabd53135'), 'title': 'è Paè, è'},
#  {'_id': ObjectId('573a13bbf29313caabd53b3e'),
#   'title': 'Saneamento Bèsico, O Filme'},
#  {'_id': ObjectId('573a13bbf29313caabd53db9'),
#   'title': 'Manda Bala (Send a Bullet)'},
#  {'_id': ObjectId('573a13bbf29313caabd543e0'), 'title': 'Embodiment of Evil'},
#  {'_id': ObjectId('573a13bbf29313caabd54db5'),
#   'title': 'O Homem Que Desafiou o Diabo'},
#  {'_id': ObjectId('573a13bcf29313caabd574d4'), 'title': 'Chega de Saudade'},
#  {'_id': ObjectId('573a13bdf29313caabd57f8b'), 'title': 'Jean Charles'},
#  {'_id': ObjectId('573a13bdf29313caabd58117'),
#   'title': 'A Grande Famèlia: O Filme'},
#  {'_id': ObjectId('573a13bdf29313caabd58a68'), 'title': 'Forbidden to Forbid'},
#  {'_id': ObjectId('573a13bdf29313caabd58aa7'), 'title': 'Santiago'},
#  {'_id': ObjectId('573a13bdf29313caabd59575'), 'title': 'Adrift'},
#  {'_id': ObjectId('573a13bdf29313caabd596c5'), 'title': 'Cèo Sem Dono'},
#  {'_id': ObjectId('573a13bdf29313caabd597b2'),
#   'title': 'Cartola - Mèsica Para os Olhos'},
#  {'_id': ObjectId('573a13bdf29313caabd59ad1'), 'title': "Lion's Den"},
#  {'_id': ObjectId('573a13bdf29313caabd5a8c8'),
#   'title': 'Estomago: A Gastronomic Story'},
#  {'_id': ObjectId('573a13bef29313caabd5b7fa'), 'title': 'Birdwatchers'},
#  {'_id': ObjectId('573a13bef29313caabd5b838'),
#   'title': 'The Best Things in the World'},
#  {'_id': ObjectId('573a13bef29313caabd5ba56'), 'title': 'The Milky Way'},
#  {'_id': ObjectId('573a13bef29313caabd5c68d'), 'title': 'Elvis & Madona'},
#  {'_id': ObjectId('573a13bff29313caabd5e088'), 'title': 'If I Were You 2'},
#  {'_id': ObjectId('573a13c0f29313caabd619d3'), 'title': 'Playing'},
#  {'_id': ObjectId('573a13c0f29313caabd61a6a'), 'title': 'Cafè com Leite'},
#  {'_id': ObjectId('573a13c0f29313caabd62817'), 'title': 'Buddies'},
#  {'_id': ObjectId('573a13c0f29313caabd62fe1'), 'title': 'The Outlaw'},
#  {'_id': ObjectId('573a13c1f29313caabd643da'),
#   'title': 'Bellini and the Devil'},
#  {'_id': ObjectId('573a13c1f29313caabd655a7'), 'title': 'Time of Peace'},
#  {'_id': ObjectId('573a13c1f29313caabd655c7'), 'title': 'Tony Manero'},
#  {'_id': ObjectId('573a13c1f29313caabd66011'), 'title': 'Chico Xavier'},
#  {'_id': ObjectId('573a13c2f29313caabd661b5'), 'title': 'VIPs'},
#  {'_id': ObjectId('573a13c2f29313caabd662ba'), 'title': 'A Mulher Invisèvel'},
#  {'_id': ObjectId('573a13c2f29313caabd66692'), 'title': 'Amazonia'},
#  {'_id': ObjectId('573a13c2f29313caabd67ef8'), 'title': 'Waste Land'},
#  {'_id': ObjectId('573a13c2f29313caabd6812d'), 'title': 'The Herb of the Rat'},
#  {'_id': ObjectId('573a13c2f29313caabd68749'), 'title': 'In Therapy'},
#  {'_id': ObjectId('573a13c2f29313caabd68996'), 'title': 'Last Stop 174'},
#  {'_id': ObjectId('573a13c2f29313caabd68b0f'),
#   'title': 'The Strange Case of Angelica'},
#  {'_id': ObjectId('573a13c3f29313caabd69162'), 'title': 'Between the Sheets'},
#  {'_id': ObjectId('573a13c3f29313caabd6ad88'),
#   'title': 'Pro Dia Nascer Feliz'},
#  {'_id': ObjectId('573a13c3f29313caabd6afd4'), 'title': 'The Assailant'},
#  {'_id': ObjectId('573a13c5f29313caabd6ec37'), 'title': 'The Story of Me'},
#  {'_id': ObjectId('573a13c5f29313caabd6fbbb'), 'title': 'Ardor'},
#  {'_id': ObjectId('573a13c5f29313caabd7003f'),
#   'title': 'Titès - A Vida Atè Parece uma Festa'},
#  {'_id': ObjectId('573a13c6f29313caabd729e6'), 'title': 'Senna'},
#  {'_id': ObjectId('573a13c6f29313caabd72b19'), 'title': "That's It"},
#  {'_id': ObjectId('573a13c7f29313caabd73eb8'),
#   'title': 'Reflexèes de um Liquidificador'},
#  {'_id': ObjectId('573a13c7f29313caabd75917'),
#   'title': 'Astral City: A Spiritual Journey'},
#  {'_id': ObjectId('573a13c8f29313caabd76b95'),
#   'title': 'The Famous and the Dead'},
#  {'_id': ObjectId('573a13c8f29313caabd779da'), 'title': 'Tropicèlia'},
#  {'_id': ObjectId('573a13c8f29313caabd77d4f'),
#   'title': 'I Travel Because I Have to, I Come Back Because I Love You'},
#  {'_id': ObjectId('573a13c8f29313caabd7840a'),
#   'title': '2012: Time for Change'},
#  {'_id': ObjectId('573a13c9f29313caabd7900c'),
#   'title': 'Loki - Arnaldo Baptista'},
#  {'_id': ObjectId('573a13c9f29313caabd7975d'), 'title': 'Natimorto'},
#  {'_id': ObjectId('573a13caf29313caabd7c53a'),
#   'title': 'Elite Squad: The Enemy Within'},
#  {'_id': ObjectId('573a13caf29313caabd7d14e'), 'title': 'Head Over Heels'},
#  {'_id': ObjectId('573a13caf29313caabd7d5ab'),
#   'title': 'Secrets of the Tribe'},
#  {'_id': ObjectId('573a13caf29313caabd7e1b2'), 'title': 'Federal Bank Heist'},
#  {'_id': ObjectId('573a13cbf29313caabd7edad'), 'title': 'Little Surfer Girl'},
#  {'_id': ObjectId('573a13cbf29313caabd80ee7'), 'title': 'Last Stop 174'},
#  {'_id': ObjectId('573a13cdf29313caabd8453c'),
#   'title': 'Once Upon a Time Veronica'},
#  {'_id': ObjectId('573a13cdf29313caabd859ee'), 'title': '360'},
#  {'_id': ObjectId('573a13cdf29313caabd86017'), 'title': 'Hard Labor'},
#  {'_id': ObjectId('573a13cef29313caabd860fc'),
#   'title': "I Don't Want to Go Back Alone"},
#  {'_id': ObjectId('573a13cef29313caabd86fd4'), 'title': '360'},
#  {'_id': ObjectId('573a13cef29313caabd8704e'), 'title': 'The Way He Looks'},
#  {'_id': ObjectId('573a13cef29313caabd88577'), 'title': 'Heleno'},
#  {'_id': ObjectId('573a13cff29313caabd88e24'),
#   'title': 'Clandestine Childhood'},
#  {'_id': ObjectId('573a13cff29313caabd89a12'), 'title': 'So Hard to Forget'},
#  {'_id': ObjectId('573a13cff29313caabd8aae0'), 'title': 'Two Rabbits'},
#  {'_id': ObjectId('573a13d0f29313caabd8d734'), 'title': 'Josè and Pilar'},
#  {'_id': ObjectId('573a13d1f29313caabd90716'), 'title': 'Boca'},
#  {'_id': ObjectId('573a13d1f29313caabd90833'), 'title': 'Capitèes da Areia'},
#  {'_id': ObjectId('573a13d2f29313caabd9186e'), 'title': 'Angels of Sex'},
#  {'_id': ObjectId('573a13d2f29313caabd918f0'), 'title': 'A Estrada 47'},
#  {'_id': ObjectId('573a13d3f29313caabd93d67'), 'title': 'Brazilian Western'},
#  {'_id': ObjectId('573a13d3f29313caabd9689a'), 'title': 'The Clown'},
#  {'_id': ObjectId('573a13d3f29313caabd9690b'), 'title': 'Trash'},
#  {'_id': ObjectId('573a13d3f29313caabd9699f'), 'title': 'Open Road'},
#  {'_id': ObjectId('573a13d4f29313caabd9776c'), 'title': 'Rènia'},
#  {'_id': ObjectId('573a13d4f29313caabd98158'), 'title': 'Quebrando o Tabu'},
#  {'_id': ObjectId('573a13d5f29313caabd9c282'),
#   'title': 'Violeta Went to Heaven'},
#  {'_id': ObjectId('573a13d5f29313caabd9cc9b'),
#   'title': 'The Man from the Future'},
#  {'_id': ObjectId('573a13d5f29313caabd9d469'), 'title': 'Mato Sem Cachorro'},
#  {'_id': ObjectId('573a13d5f29313caabd9d91b'), 'title': 'Found Memories'},
#  {'_id': ObjectId('573a13d6f29313caabda1229'),
#   'title': 'Artificial Paradises'},
#  {'_id': ObjectId('573a13d7f29313caabda13ef'), 'title': 'Amor?'},
#  {'_id': ObjectId('573a13d7f29313caabda25e0'), 'title': "Father's Chair"},
#  {'_id': ObjectId('573a13d7f29313caabda30f4'), 'title': 'Estamos Juntos'},
#  {'_id': ObjectId('573a13d7f29313caabda32fd'), 'title': 'Xingu'},
#  {'_id': ObjectId('573a13d7f29313caabda40ba'), 'title': 'Tabu'},
#  {'_id': ObjectId('573a13d7f29313caabda4c8d'), 'title': 'Southwest'},
#  {'_id': ObjectId('573a13d8f29313caabda5a20'), 'title': 'Reis e Ratos'},
#  {'_id': ObjectId('573a13d8f29313caabda6225'), 'title': 'Neighboring Sounds'},
#  {'_id': ObjectId('573a13d8f29313caabda6ac8'), 'title': 'Futuro Beach'},
#  {'_id': ObjectId('573a13d8f29313caabda6bf3'), 'title': 'Rat Fever'},
#  {'_id': ObjectId('573a13d8f29313caabda7307'), 'title': 'E Aè... Comeu?'},
#  {'_id': ObjectId('573a13d8f29313caabda7a55'),
#   'title': 'Reaching for the Moon'},
#  {'_id': ObjectId('573a13d8f29313caabda8616'),
#   'title': 'Rio 2096: A Story of Love and Fury'},
#  {'_id': ObjectId('573a13daf29313caabdac3b7'), 'title': 'Head Over Heels 2'},
#  {'_id': ObjectId('573a13dbf29313caabdaf211'), 'title': 'Cine Hollièdy'},
#  {'_id': ObjectId('573a13dbf29313caabdaf274'),
#   'title': 'The Boy in the Mirror'},
#  {'_id': ObjectId('573a13dbf29313caabdaf845'), 'title': 'Revolution'},
#  {'_id': ObjectId('573a13dcf29313caabdb2e71'),
#   'title': 'My Sweet Orange Tree'},
#  {'_id': ObjectId('573a13ddf29313caabdb5059'),
#   'title': 'My Mom Is a Character'},
#  {'_id': ObjectId('573a13def29313caabdb55cb'), 'title': 'Elena'},
#  {'_id': ObjectId('573a13def29313caabdb666a'), 'title': 'Jauja'},
#  {'_id': ObjectId('573a13e0f29313caabdb9e95'),
#   'title': 'The Day That Lasted 21 Years'},
#  {'_id': ObjectId('573a13e0f29313caabdba100'), 'title': 'Love Is Strange'},
#  {'_id': ObjectId('573a13e2f29313caabdbdbf1'), 'title': 'Way Beyond Weight'},
#  {'_id': ObjectId('573a13e3f29313caabdbf8e8'), 'title': 'Wolf at the Door'},
#  {'_id': ObjectId('573a13e4f29313caabdc1def'), 'title': 'Corazèn de leèn'},
#  {'_id': ObjectId('573a13e5f29313caabdc33f1'), 'title': 'Boa Sorte'},
#  {'_id': ObjectId('573a13e5f29313caabdc426f'),
#   'title': "Sur le chemin de l'ècole"},
#  {'_id': ObjectId('573a13e6f29313caabdc4c52'),
#   'title': 'Meu Passado Me Condena: O Filme'},
#  {'_id': ObjectId('573a13e6f29313caabdc527a'), 'title': 'Getèlio'},
#  {'_id': ObjectId('573a13e7f29313caabdc7b7d'), 'title': 'Tim Maia'},
#  {'_id': ObjectId('573a13e8f29313caabdc93d7'),
#   'title': 'The Boy and the World'},
#  {'_id': ObjectId('573a13e8f29313caabdcb19a'), 'title': 'A Estrada 47'},
#  {'_id': ObjectId('573a13e9f29313caabdccc55'),
#   'title': 'The Mystery of Happiness'},
#  {'_id': ObjectId('573a13e9f29313caabdcda62'),
#   'title': 'Eu Nèo Faèo a Menor Ideia do Que Eu Tè Fazendo Com a Minha Vida'},
#  {'_id': ObjectId('573a13ecf29313caabdd22df'), 'title': 'Casa Grande'},
#  {'_id': ObjectId('573a13eef29313caabdd5610'),
#   'title': 'A Histèria Da Eternidade'},
#  {'_id': ObjectId('573a13eff29313caabdd8991'),
#   'title': 'The Salt of the Earth'},
#  {'_id': ObjectId('573a13f0f29313caabdda839'), 'title': 'The Second Mother'},
#  {'_id': ObjectId('573a13f1f29313caabddbbb0'), 'title': 'Paulina'},
#  {'_id': ObjectId('573a13f3f29313caabdde9e1'), 'title': 'August Winds'},
#  {'_id': ObjectId('573a13f5f29313caabde36e4'), 'title': 'Olmo & the Seagull'},
#  {'_id': ObjectId('573a13f6f29313caabde5404'), 'title': 'White Out, Black In'},
#  {'_id': ObjectId('573a13f7f29313caabde5fa9'),
#   'title': 'The Mysterious Death of Pèrola'},
#  {'_id': ObjectId('573a13f7f29313caabde7453'), 'title': 'Seashore'},
#  {'_id': ObjectId('573a13f9f29313caabdeb527'), 'title': 'Land and Shade'}]
